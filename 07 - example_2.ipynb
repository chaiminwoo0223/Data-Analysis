# %% [markdown]
# <a href="https://colab.research.google.com/github/chaiminwoo0223/Data-Analysis/blob/main/07%20-%20example_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
economics = pd.read_csv('/content/drive/MyDrive/수업/데이터 분석 입문/강의자료/Data/economics.csv')
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066

# %%
# 선 그래프 그리기
sns.lineplot(data = economics,x = 'date',y = 'unemploy')

# %%
# 날짜 시간 타입 변수 만들기
economics['date2'] = pd.to_datetime(economics['date'])
economics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 574 entries, 0 to 573
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      574 non-null    object
#  1   pce       574 non-null    float64
#  2   pop       574 non-null    float64
#  3   psavert   574 non-null    float64
#  4   uempmed   574 non-null    float64
#  5   unemploy  574 non-null    int64
#  6   date2     574 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(4), int64(1), object(1)
# memory usage: 31.5+ KB

# %%
economics[['date','date2']]
# Out:
#            date      date2
# 0    1967-07-01 1967-07-01
# 1    1967-08-01 1967-08-01
# 2    1967-09-01 1967-09-01
# 3    1967-10-01 1967-10-01
# 4    1967-11-01 1967-11-01
# ..          ...        ...
# 569  2014-12-01 2014-12-01
# 570  2015-01-01 2015-01-01
# 571  2015-02-01 2015-02-01
# 572  2015-03-01 2015-03-01
# 573  2015-04-01 2015-04-01
#
# [574 rows x 2 columns]

# %%
economics['date2'].dt.year # 연 추출
# Out:
# 0      1967
# 1      1967
# 2      1967
# 3      1967
# 4      1967
#        ...
# 569    2014
# 570    2015
# 571    2015
# 572    2015
# 573    2015
# Name: date2, Length: 574, dtype: int64

# %%
economics['date2'].dt.month # 월 추출
# Out:
# 0       7
# 1       8
# 2       9
# 3      10
# 4      11
#        ..
# 569    12
# 570     1
# 571     2
# 572     3
# 573     4
# Name: date2, Length: 574, dtype: int64

# %%
economics['date2'].dt.day # 일 추출
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 569    1
# 570    1
# 571    1
# 572    1
# 573    1
# Name: date2, Length: 574, dtype: int64

# %%
# 연도 변수 추가하기
economics['year'] = economics['date2'].dt.year
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy      date2  year
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944 1967-07-01  1967
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945 1967-08-01  1967
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958 1967-09-01  1967
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143 1967-10-01  1967
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066 1967-11-01  1967

# %%
# x축에 연도 표시하기
sns.lineplot(data = economics,x = 'year',y = 'unemploy')

# %%
# 신뢰구간 제거하기
sns.lineplot(data = economics,x = 'year',y = 'unemploy',ci = None)

# %%
mpg = pd.read_csv('/content/drive/MyDrive/수업/데이터 분석 입문/강의자료/Data/mpg.csv')
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
sns.boxplot(data = mpg,x = 'drv',y = 'hwy')

# %%
# 실습

# %%
# 문제1

# %%
sns.lineplot(data = economics,x = 'year',y = 'psavert',ci = None)

# %%
# 문제2

# %%
economics['month'] = economics['date2'].dt.month
economics.head()
# Out:
#          date    pce       pop  psavert  uempmed  unemploy      date2  year  \
# 0  1967-07-01  506.7  198712.0     12.6      4.5      2944 1967-07-01  1967
# 1  1967-08-01  509.8  198911.0     12.6      4.7      2945 1967-08-01  1967
# 2  1967-09-01  515.6  199113.0     11.9      4.6      2958 1967-09-01  1967
# 3  1967-10-01  512.2  199311.0     12.9      4.9      3143 1967-10-01  1967
# 4  1967-11-01  517.4  199498.0     12.8      4.7      3066 1967-11-01  1967
#
#    month
# 0      7
# 1      8
# 2      9
# 3     10
# 4     11

# %%
test = economics.query('year == 2014')
test
# Out:
#            date      pce         pop  psavert  uempmed  unemploy      date2  \
# 558  2014-01-01  11512.5  317593.923      7.1     15.4     10202 2014-01-01
# 559  2014-02-01  11566.2  317753.883      7.3     15.9     10349 2014-02-01
# 560  2014-03-01  11643.0  317917.203      7.4     15.8     10380 2014-03-01
# 561  2014-04-01  11702.6  318089.218      7.4     15.7      9702 2014-04-01
# 562  2014-05-01  11748.4  318269.505      7.4     14.6      9859 2014-05-01
# 563  2014-06-01  11817.0  318464.152      7.4     13.8      9460 2014-06-01
# 564  2014-07-01  11860.5  318662.368      7.5     13.1      9608 2014-07-01
# 565  2014-08-01  11944.3  318893.786      7.2     12.9      9599 2014-08-01
# 566  2014-09-01  11957.4  319125.296      7.4     13.4      9262 2014-09-01
# 567  2014-10-01  12023.0  319353.734      7.2     13.6      8990 2014-10-01
# 568  2014-11-01  12051.4  319564.209      7.3     13.0      9090 2014-11-01
# ...

# %%
sns.lineplot(data = test,x = 'month',y = 'psavert',ci = None)

# %%
# 실습2

# %%
test2 = mpg.query("category == 'compact' | category == 'subcompact' | category == 'suv'")
test2
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...         ...    ...   ...  ...         ...  ..  ...  ... ..
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
# 223   volkswagen  new beetle    2.0  1999    4  manual(m5)   f   21   29  r
# 224   volkswagen  new beetle    2.0  1999    4    auto(l4)   f   19   26  r
# 225   volkswagen  new beetle    2.5  2008    5  manual(m5)   f   20   28  r
# 226   volkswagen  new beetle    2.5  2008    5    auto(s6)   f   20   29  r
#
#        category
# 0       compact
# 1       compact
# ...

# %%
sns.boxplot(data = test2,x = 'category',y = 'cty')

# %%
test3 = mpg.query('category in ["compact","subcompact","suv"]')
test3
# Out:
#     manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl  \
# 0           audi          a4    1.8  1999    4    auto(l5)   f   18   29  p
# 1           audi          a4    1.8  1999    4  manual(m5)   f   21   29  p
# 2           audi          a4    2.0  2008    4  manual(m6)   f   20   31  p
# 3           audi          a4    2.0  2008    4    auto(av)   f   21   30  p
# 4           audi          a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...         ...    ...   ...  ...         ...  ..  ...  ... ..
# 222   volkswagen  new beetle    1.9  1999    4    auto(l4)   f   29   41  d
# 223   volkswagen  new beetle    2.0  1999    4  manual(m5)   f   21   29  r
# 224   volkswagen  new beetle    2.0  1999    4    auto(l4)   f   19   26  r
# 225   volkswagen  new beetle    2.5  2008    5  manual(m5)   f   20   28  r
# 226   volkswagen  new beetle    2.5  2008    5    auto(s6)   f   20   29  r
#
#        category
# 0       compact
# 1       compact
# ...

# %%
sns.boxplot(data = test3,x = 'category',y = 'cty')
